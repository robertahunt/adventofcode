# %%
import os
import re
import aocd
import pandas as pd
from aocd import submit

# %%
# My solution

data = aocd.get_data(day=1, year=2022).split('\n\n')
most_calories = 0
for elf in data:
    calories = map(int, elf.split('\n'))
    total = sum(calories)
    if total > most_calories:
        most_calories = total
most_calories
# Out:
# ['2159\n2527\n2441\n3299\n1672\n3025\n2820\n6821\n3201\n1204\n1208\n4861\n5621',
#  '5580\n18071',
#  '8803\n1667\n4173\n9404\n9718\n10311',
#  '12237\n5068\n9824\n6535',
#  '25484',
#  '18598\n2851\n13577',
#  '13719\n9147\n11204\n8554\n11796\n1297',
#  '43055',
#  '8156\n4616',
#  '16383\n17036\n16017\n18569',
#  '33581\n10017',
#  '65566',
#  '5750\n6961\n4494\n11117\n3392\n10471\n3490',
#  '7006\n7526\n9302\n1454\n4039\n8067\n9321\n8888\n7380',
#  '8543\n2106\n2986\n3465\n9592\n11240\n1795',
#  '4396\n27967',
#  '8091\n19515\n1282',
#  '6241\n8946\n6665\n5163\n2224\n8684\n6631\n5866',
#  '5565\n6118\n1856\n3227\n4501\n3024\n5745\n3988\n1590\n5111\n4457\n3108\n3165\n3508\n4629',
#  '1455\n4809\n5650\n5472\n4673\n1775\n3080\n5282\n3552\n3875\n4691\n7352',
#  '7325\n2121\n2751\n10300\n1939\n3782\n3635\n1801',
#  '8562\n15236\n18996\n18271',
#  '9673\n9270\n15540\n5842\n10343',
#  '7384\n30187',
#  '7578\n7909\n8514\n5775\n3455',
#  '2617\n30132',
#  '6414',
# ...

# %%
# Part 2
data = [sum(map(int, elf.split('\n'))) for elf in data]
data = sorted(data)

# %%
sum(data[-3:])
# Out:
# 205615

# %%
# Cleaned

# Part 1

data = aocd.get_data(day=1, year=2022).split('\n\n')
